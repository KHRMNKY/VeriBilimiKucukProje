# %% [markdown]
# <a href="https://colab.research.google.com/github/kahramankaya/VeriBilimiKucukProje/blob/main/normalizasyon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.read_csv("/content/purchased.csv")
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  51000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  41.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
for i in range(4):
    df = pd.concat([df,df])
df
# Out:
#     Country   Age   Salary Purchased
# 0    France  44.0  72000.0        No
# 1     Spain  27.0  48000.0       Yes
# 2   Germany  30.0  54000.0        No
# 3     Spain  38.0  61000.0        No
# 4   Germany  40.0  51000.0       Yes
# ..      ...   ...      ...       ...
# 5    France  35.0  58000.0       Yes
# 6     Spain  41.0  52000.0        No
# 7    France  48.0  79000.0       Yes
# 8   Germany  50.0  83000.0        No
# 9    France  37.0  67000.0       Yes
#
# [40960 rows x 4 columns]

# %%
df.reset_index()
# Out:
#        index  Country   Age   Salary Purchased
# 0          0   France  44.0  72000.0        No
# 1          1    Spain  27.0  48000.0       Yes
# 2          2  Germany  30.0  54000.0        No
# 3          3    Spain  38.0  61000.0        No
# 4          4  Germany  40.0  51000.0       Yes
# ...      ...      ...   ...      ...       ...
# 40955      5   France  35.0  58000.0       Yes
# 40956      6    Spain  41.0  52000.0        No
# 40957      7   France  48.0  79000.0       Yes
# 40958      8  Germany  50.0  83000.0        No
# 40959      9   France  37.0  67000.0       Yes
#
# [40960 rows x 5 columns]

# %%
df_normalızatıon=df.reset_index().drop("index",axis=1).copy()
df_normalızatıon
# Out:
#        Country   Age   Salary Purchased
# 0       France  44.0  72000.0        No
# 1        Spain  27.0  48000.0       Yes
# 2      Germany  30.0  54000.0        No
# 3        Spain  38.0  61000.0        No
# 4      Germany  40.0  51000.0       Yes
# ...        ...   ...      ...       ...
# 40955   France  35.0  58000.0       Yes
# 40956    Spain  41.0  52000.0        No
# 40957   France  48.0  79000.0       Yes
# 40958  Germany  50.0  83000.0        No
# 40959   France  37.0  67000.0       Yes
#
# [40960 rows x 4 columns]

# %% [markdown]
# #normalızasyon yaptım kısa yoldan.

# %%
scaler = MinMaxScaler()
scaler.fit(df_normalızatıon[["Age","Salary"]])
pd.DataFrame(scaler.transform(df_normalızatıon[["Age","Salary"]]))
# Out:
#               0         1
# 0      0.739130  0.685714
# 1      0.000000  0.000000
# 2      0.130435  0.171429
# 3      0.478261  0.371429
# 4      0.565217  0.085714
# ...         ...       ...
# 40955  0.347826  0.285714
# 40956  0.608696  0.114286
# 40957  0.913043  0.885714
# 40958  1.000000  1.000000
# 40959  0.434783  0.542857
#
# [40960 rows x 2 columns]

# %% [markdown]
# #normalızasyon yaptım uzun yoldan
# #formül:
# ![image.png](data:image/png;base64,...)

# %%
df_norm1=(df_normalızatıon["Age"]-df_normalızatıon["Age"].min())/(df_normalızatıon['Age'].max()-df_normalızatıon['Age'].min())
df_norm2=(df_normalızatıon["Salary"]-df_normalızatıon["Salary"].min())/(df_normalızatıon['Salary'].max()-df_normalızatıon['Salary'].min())
pd.concat([df_norm1,df_norm2],axis=1)
# Out:
#             Age    Salary
# 0      0.739130  0.685714
# 1      0.000000  0.000000
# 2      0.130435  0.171429
# 3      0.478261  0.371429
# 4      0.565217  0.085714
# ...         ...       ...
# 40955  0.347826  0.285714
# 40956  0.608696  0.114286
# 40957  0.913043  0.885714
# 40958  1.000000  1.000000
# 40959  0.434783  0.542857
#
# [40960 rows x 2 columns]
